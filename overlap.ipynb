# %%
import pandas as pd
import re
from tqdm import tqdm


df = pd.read_csv("train.csv")


def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"[^a-z\s]", " ", text)
    return re.sub(r"\s+", " ", text).strip()

# ----------------------------
# 3. Extract skills from text
# ----------------------------
def extract_skills(text):
    # لو عندك عمود جاهز اسمه skills، ممكن نستخدمه بدلاً من دي
    if pd.isna(text):
        return []
    
    text = clean_text(text)
    tokens = text.split()
    
    # مثال بسيط لقائمة skills keywords (ممكن نحدثها حسب الداتا بتاعتك)
    skill_keywords = [
        'python', 'sql', 'excel', 'powerbi', 'tableau', 'machine', 'learning',
        'pandas', 'numpy', 'communication', 'statistics', 'ai', 'deep', 'data', 'analysis'
    ]
    
    found = [w for w in tokens if w in skill_keywords]
    return list(set(found))

# ----------------------------
# 4. Apply skill extraction
# ----------------------------
df['cv_skills'] = df['resume_text'].apply(extract_skills)
df['jd_skills'] = df['job_description_text'].apply(extract_skills)

# ----------------------------
# 5. Calculate overlap and missing
# ----------------------------
def skill_overlap(cv_skills, jd_skills):
    cv_set = set(cv_skills)
    jd_set = set(jd_skills)
    if not jd_set:
        return 0, [], []
    
    overlap = cv_set.intersection(jd_set)
    missing = jd_set - cv_set
    
    overlap_ratio = len(overlap) / len(jd_set)
    return overlap_ratio, list(overlap), list(missing)

tqdm.pandas()
df['skill_overlap_ratio'], df['common_skills'], df['missing_skills'] = zip(*df.progress_apply(
    lambda row: skill_overlap(row['cv_skills'], row['jd_skills']), axis=1
))

# ----------------------------
# 6. Display results
# ----------------------------
pd.set_option('display.max_colwidth', 120)
print(df[['cv_skills', 'jd_skills', 'skill_overlap_ratio', 'common_skills', 'missing_skills']].head(10))
# Out:
# 100%|████████████████████████████████████| 6241/6241 [00:00<00:00, 28601.14it/s]
#                                            cv_skills  \
# 0                                            [excel]
# 1                 [analysis, communication, machine]
# 2                                                 []
# 3                       [communication, data, excel]
# 4  [communication, analysis, data, excel, sql, deep]
# 5                    [analysis, communication, data]
# 6                                  [analysis, excel]
# 7                    [communication, learning, data]
# 8             [analysis, deep, communication, excel]
# 9                         [sql, communication, data]
#
#                       jd_skills  skill_overlap_ratio    common_skills  \
# 0                  [sql, excel]             0.500000          [excel]
# 1  [communication, data, excel]             0.333333  [communication]
# 2       [python, communication]             0.000000               []
# 3               [communication]             1.000000  [communication]
# 4    [ai, deep, data, learning]             0.500000     [deep, data]
# 5                        [data]             1.000000           [data]
# 6              [analysis, data]             0.500000       [analysis]
# 7                            []             0.000000               []
# 8                            []             0.000000               []
# 9               [communication]             1.000000  [communication]
#
#             missing_skills
# 0                    [sql]
# 1            [data, excel]
# 2  [python, communication]
# 3                       []
# 4           [ai, learning]
# 5                       []
# 6                   [data]
# 7                       []
# 8                       []
# 9                       []

# %%
import pandas as pd
import re
from tqdm import tqdm

# ----------------------------
# 1. Load dataset
# ----------------------------
df = pd.read_csv("train.csv")

# ----------------------------
# 2. Clean text helper
# ----------------------------
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"[^a-z\s]", " ", text)
    return re.sub(r"\s+", " ", text).strip()

# ----------------------------
# 3. Parse skills column safely
# ----------------------------
def parse_skills(skills):
    """
    يحاول يقرأ عمود skills سواء مكتوب كـ list أو نص
    """
    if isinstance(skills, str):
        # لو مكتوبة كـ string list زي ['python','sql']
        skills = re.findall(r"[a-zA-Z+#]+", skills.lower())
    elif isinstance(skills, list):
        skills = [s.lower() for s in skills]
    else:
        return []
    return list(set(skills))

# ----------------------------
# 4. Clean skills from dataset
# ----------------------------
df['cv_skills'] = df['cv_skills'].apply(parse_skills) if 'cv_skills' in df.columns else df['resume_text'].apply(lambda x: re.findall(r"[a-zA-Z+#]+", str(x).lower()))
df['jd_skills'] = df['jd_skills'].apply(parse_skills) if 'jd_skills' in df.columns else df['job_description_text'].apply(lambda x: re.findall(r"[a-zA-Z+#]+", str(x).lower()))

# ----------------------------
# 5. Skill overlap function
# ----------------------------
def skill_overlap(cv_skills, jd_skills):
    cv_set = set(cv_skills)
    jd_set = set(jd_skills)
    if not jd_set:
        return 0, [], []
    
    overlap = cv_set.intersection(jd_set)
    missing = jd_set - cv_set
    
    overlap_ratio = len(overlap) / len(jd_set)
    return overlap_ratio, list(overlap), list(missing)

# ----------------------------
# 6. Apply to dataset
# ----------------------------
tqdm.pandas()
df['skill_overlap_ratio'], df['common_skills'], df['missing_skills'] = zip(*df.progress_apply(
    lambda row: skill_overlap(row['cv_skills'], row['jd_skills']), axis=1
))

# ----------------------------
# 7. Display results
# ----------------------------
pd.set_option('display.max_colwidth', 120)
print(df[['cv_skills', 'jd_skills', 'skill_overlap_ratio', 'common_skills', 'missing_skills']].head(10))
# Out:
# 100%|█████████████████████████████████████| 6241/6241 [00:00<00:00, 6258.30it/s]
#                                                                                                                  cv_skills  \
# 0  [summaryhighly, motivated, sales, associate, with, extensive, customer, service, and, sales, experience, outgoing, s...
# 1  [professional, summarycurrently, working, with, caterpillar, as, an, contract, employee, active, in, several, npi, a...
# 2  [summaryi, started, my, construction, career, in, june, of, in, jacksonville, florida, as, an, electrical, apprentic...
# 3  [summarycertified, electrical, foremanwith, thirteen, years, of, experience, in, the, implementation, of, electrical...
# 4  [summarywith, extensive, experience, in, business, requirement, analysis, with, sdlc, processing, experience, includ...
# 5  [summarysolution, oriented, results, driven, strategic, sales, executive, with, a, proven, track, record, in, genera...
# 6  [summarya, position, in, a, company, that, will, utilize, my, abilities, in, accounting, and, finance, while, provid...
# 7  [summaryto, participate, as, a, team, member, in, a, dynamic, work, environment, focused, on, promoting, business, g...
# 8  [summarymore, than, ten, years, of, progressive, experience, in, manufacturing, accountingcurrently, preparing, for,...
# 9  [summarycertified, software, development, professional, solutions, driven, developer, with, a, multi, year, record, ...
#
#                                                                                                                  jd_skills  \
# 0  [net, source, inc, is, an, award, winning, total, workforce, solutions, company, recognized, by, staffing, industry,...
# 1  [at, salas, obrien, we, tell, our, clients, that, were, engineered, for, impact, this, passion, for, making, a, diff...
# 2  [schweitzer, engineering, laboratories, sel, infrastructure, defense, division, seeks, a, talented, individual, for,...
# 3  [mizick, miller, company, inc, is, looking, for, a, dynamic, individual, to, join, our, team, this, is, a, great, op...
# 4  [life, at, capgemini, capgemini, supports, all, aspects, of, your, well, being, throughout, the, changing, stages, o...
# 5  [responsibilitieslead, and, provide, day, to, day, support, for, assigned, navy, federal, development, efforts, in, ...
# 6  [senior, salesforce, software, engineer, salesforce, declarative, and, programmatic, customization, visa, independen...
# 7  [w, only, software, engineer, month, contract, remote, team, based, in, mounds, view, mn, top, skills, javascript, v...
# 8  [calling, all, innovators, find, your, future, at, fiserv, were, fiserv, a, global, leader, in, fintech, and, paymen...
# 9  [who, we, arewere, reinventing, the, egg, protein, business, at, ovainnovations, we, deliver, a, better, value, on, ...
#
#    skill_overlap_ratio  \
# 0             0.192073
# 1             0.237179
# 2             0.156028
# 3             0.254545
# 4             0.254505
# 5             0.251366
# 6             0.217949
# 7             0.181102
# 8             0.119438
# 9             0.218241
#
#                                                                                                              common_skills  \
# 0  [solutions, such, to, worked, over, life, use, various, as, board, environment, our, related, extensive, state, and,...
# 1  [professional, to, that, use, is, various, as, our, engineer, will, related, across, and, electrical, obtain, techno...
# 2  [such, factors, to, following, our, as, related, and, processes, electrical, owners, recommendations, quality, ident...
# 3  [to, is, environment, and, excellent, year, the, degree, great, written, for, with, inc, work, in, a, deadlines, det...
# 4  [be, ensure, as, programs, microsoft, resolve, quality, duties, by, consistent, day, it, availability, financial, te...
# 5  [solutions, to, years, is, develops, as, developing, and, processes, preparation, requirements, execution, s, knowle...
# 6     [financial, that, to, for, understanding, of, with, procedures, log, experience, analysis, a, i, and, w, an, senior]
# 7  [that, to, ensure, and, process, requirements, the, projects, of, for, education, responsible, with, university, in,...
# 8  [build, to, software, end, ensure, communicate, is, years, as, and, report, investment, process, balance, policies, ...
# 9  [professional, to, were, software, organizational, multiple, as, structure, key, and, accounting, processes, attenti...
#
#                                                                                                             missing_skills
# 0  [specifications, top, be, is, you, inwith, methodologies, current, emphasis, creative, total, technology, banking, e...
# 1  [build, limitless, desire, four, be, you, programs, microsoft, lasting, applicants, clean, academic, accounting, her...
# 2  [box, conducting, be, retirement, is, you, top, sick, offer, paid, communicate, programs, range, selinc, current, ne...
# 3  [professional, box, be, retirement, you, send, our, mizick, microsoft, accounting, group, this, businesses, miller, ...
# 4  [get, top, offer, range, relief, deploy, cryopreservation, diverse, wages, cicd, tutoring, consider, share, unit, ww...
# 5  [components, following, compliance, methodologies, css, rest, technology, integrity, latest, day, implementation, bo...
# 6  [troubleshooting, salesforce, software, please, is, platform, declarative, product, engineer, only, complex, builder...
# 7  [components, top, be, dockerjsonpostgresqlreact, haves, apispring, duties, target, obtained, development, area, inte...
# 8  [top, send, range, conducted, stability, mobility, by, perks, diverse, serving, target, elevate, critical, share, op...
# 9  [generally, active, specifications, be, ensure, accepted, rolereporting, you, manufacturing, is, our, microsoft, ran...
